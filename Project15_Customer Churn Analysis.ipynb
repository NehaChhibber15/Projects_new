# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Customer Curn.csv")

# %%
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding shape of dataset
df.shape
# Out:
# (3333, 21)

# %%
#finding info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# Observation: Here we see that there is no null value present in the dataset. Some of the columns are in object data type.

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: Here we can see that there is no null value present in our data set.

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# Observation: Here we can see the average value of each column. There is no outliers present in the data.

# %%
df_cat=df.select_dtypes(exclude=['number','bool_','float_'])
df_cat.head()
# Out:
#   state phone number international plan voice mail plan
# 0    KS     382-4657                 no             yes
# 1    OH     371-7191                 no             yes
# 2    NJ     358-1921                 no              no
# 3    OH     375-9999                yes              no
# 4    OK     330-6626                yes              no

# %%
df_num=df.select_dtypes(exclude=['bool_','object_'])
df_num.head()
# Out:
#    account length  area code  number vmail messages  total day minutes  \
# 0             128        415                     25              265.1
# 1             107        415                     26              161.6
# 2             137        415                      0              243.4
# 3              84        408                      0              299.4
# 4              75        415                      0              166.7
#
#    total day calls  total day charge  total eve minutes  total eve calls  \
# 0              110             45.07              197.4               99
# 1              123             27.47              195.5              103
# 2              114             41.38              121.2              110
# 3               71             50.90               61.9               88
# 4              113             28.34              148.3              122
#
#    total eve charge  total night minutes  total night calls  \
# ...

# %%
df.corr()
# Out:
#                         account length  area code  number vmail messages  \
# account length                1.000000  -0.012463              -0.004628
# area code                    -0.012463   1.000000              -0.001994
# number vmail messages        -0.004628  -0.001994               1.000000
# total day minutes             0.006216  -0.008264               0.000778
# total day calls               0.038470  -0.009646              -0.009548
# total day charge              0.006214  -0.008264               0.000776
# total eve minutes            -0.006757   0.003580               0.017562
# total eve calls               0.019260  -0.011886              -0.005864
# total eve charge             -0.006745   0.003607               0.017578
# total night minutes          -0.008955  -0.005825               0.007681
# total night calls            -0.013176   0.016522               0.007123
# total night charge           -0.008960  -0.005845               0.007663
# ...

# %%
#visualization of correlation by using heatmap
plt.subplots(figsize=(18, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation: Here we can see that some features are highly and equally correlated. So we can drop one of them.

# %%
#dropping the columns having correation
df.drop(['total day charge','total eve charge','total night charge','total intl charge'],axis=1,inplace=True)

# %%
df
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# # Univariable Analysis

# %%
df_num.hist(figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024524737B88>,
# ...
#       dtype=object)

# %% [markdown]
# Observation: here we observe that data is skewed in customer service call, number vmail messages,total intl calls. Rest of the data looks normalize.

# %%
#categorical attributes visualization
#data visualization by countplot

           


sns.countplot(df['churn']) 
plt.show()

# %%
sns.countplot(df['international plan'])

# %% [markdown]
# Observation: Here we observe that the data is imbalanced.

# %%
sns.countplot(df['voice mail plan'])

# %% [markdown]
# Observation: Here we observe that this data is imbalanced too.

# %% [markdown]
# # Bivariable Analysis

# %%
#visualizing categorical data
#categorical attributes visualization
#data visualization by countplot

#Now let us visualize that how international plan and churn related to each other
plt.subplots(figsize=(12,4))
sns.set_style('whitegrid')
sns.countplot(x='international plan',hue='churn',data=df)

# %% [markdown]
# Observation:Here we observe that churn out in international plan is less.

# %%
#Now let us visualize that how voice mail plan and churn related to each other
plt.subplots(figsize=(12,4))
sns.set_style('whitegrid')
sns.countplot(x='voice mail plan',hue='churn',data=df)

# %% [markdown]
# Observation: Here we observe that people having no voice mail plan are dropping the services more.

# %%
#Now let us visualize that how state and churn related to each other
plt.subplots(figsize=(19,4))
sns.set_style('whitegrid')
sns.countplot(x='state',hue='churn',data=df)

# %% [markdown]
# Observation: Here we observed that in WW,IA,VA, AZ,HI,AK,NM,TM cases of churn is very less. As this column is not giving any acurate relation. So we way drop this column.

# %%
#transforming the non-numeric data to numeric data by using label encoder
from sklearn.preprocessing import LabelEncoder

for col in df.columns:
    if df[col].dtype==np.number:
        continue
    df[col]=LabelEncoder().fit_transform(df[col])

# %%
df.drop('state',axis=1)
# Out:
#       account length  area code  phone number  international plan  \
# 0                126          1          1926                   0
# 1                105          1          1575                   0
# 2                135          1          1117                   0
# 3                 82          0          1707                   1
# 4                 73          1           110                   1
# ...              ...        ...           ...                 ...
# 3328             189          1          3057                   0
# 3329              66          1          1528                   0
# 3330              26          2            42                   0
# 3331             182          2          1331                   1
# 3332              72          1          2559                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# 0                   1                     19              265.1
# ...

# %%
#spliting the data into dependent and independent variable
x=df.iloc[:,0:-1]
x
# Out:
#       state  account length  area code  phone number  international plan  \
# 0        16             126          1          1926                   0
# 1        35             105          1          1575                   0
# 2        31             135          1          1117                   0
# 3        35              82          0          1707                   1
# 4        36              73          1           110                   1
# ...     ...             ...        ...           ...                 ...
# 3328      3             189          1          3057                   0
# 3329     49              66          1          1528                   0
# 3330     39              26          2            42                   0
# 3331      6             182          2          1331                   1
# 3332     42              72          1          2559                   0
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
y=df.iloc[:,-1]

# %%
#dependent variable
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: churn, Length: 3333, dtype: int64

# %%
#nomalizing the curve
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x=scale.fit_transform(x)

# %%
#importing models and metrics from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#finding best randomstate for train test split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=accuracy_score(y_test,y_pred)
        print("accuracy score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max accuracy score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
#finding best random state
from sklearn.linear_model import LogisticRegression
regr=LogisticRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# accuracy score corresponding to 42 is 0.8515742128935532
# accuracy score corresponding to 43 is 0.8770614692653673
# accuracy score corresponding to 44 is 0.8665667166416792
# accuracy score corresponding to 45 is 0.856071964017991
# accuracy score corresponding to 46 is 0.8710644677661169
# accuracy score corresponding to 47 is 0.8725637181409296
# accuracy score corresponding to 48 is 0.863568215892054
# accuracy score corresponding to 49 is 0.8650674662668666
# accuracy score corresponding to 50 is 0.8470764617691154
# accuracy score corresponding to 51 is 0.8605697151424287
# accuracy score corresponding to 52 is 0.856071964017991
# accuracy score corresponding to 53 is 0.8515742128935532
# accuracy score corresponding to 54 is 0.8470764617691154
# accuracy score corresponding to 55 is 0.8530734632683659
# accuracy score corresponding to 56 is 0.8740629685157422
# accuracy score corresponding to 57 is 0.863568215892054
# accuracy score corresponding to 58 is 0.841079460269865
# ...

# %%
#dividing the data into train and test by using train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=68)

# %%
#Importing models for classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Hyperparameter tunning by using GridSearchCV¶#

# %%
#parameters for knn
neighbors={"n_neighbors":range(1,20)}
knc=KNeighborsClassifier()
gknc=GridSearchCV(knc,neighbors,cv=10)
gknc.fit(x,y)
gknc.best_params_
# Out:
# {'n_neighbors': 5}

# %%
#parameters for random forest
rfc = RandomForestClassifier()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfc, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'log2',
#  'min_samples_split': 8,
#  'n_estimators': 30}

# %%
#best parameters for AdaBoostClassifier
n_estimators={"n_estimators":range(1,25)}
adc=AdaBoostClassifier()
gadc=GridSearchCV(adc,n_estimators,cv=10)
gadc.fit(x,y)
gadc.best_params_
# Out:
# {'n_estimators': 10}

# %%
#best parameters for decisiontreeclassifier
param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
dtc=DecisionTreeClassifier()    
gdtc=GridSearchCV(dtc, param_grid, cv=5)
gdtc.fit(x, y)
gdtc.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 7}

# %%
#best parameters for support vector classifier
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svc=SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.9138903521212367
# rbf
# {'C': 10, 'kernel': 'rbf'}

# %%
#best parameter for gradiantboosting classifier
n_estimators={"n_estimators":range(1,25)}
gbc=GradientBoostingClassifier()
gc=GridSearchCV(gbc,n_estimators,cv=10)
gc.fit(x,y)
gc.best_params_
# Out:
# {'n_estimators': 24}

# %%
#fitting best parameters
knc=KNeighborsClassifier(n_neighbors=5)
svc=SVC(C= 10, kernel='rbf')
dtc=DecisionTreeClassifier(criterion='gini', max_depth=7)
rfc=RandomForestClassifier(bootstrap= False, max_features='log2',min_samples_split= 8,n_estimators=30)
adc=AdaBoostClassifier(n_estimators=10)
gbc=GradientBoostingClassifier(n_estimators=24)
gb=GaussianNB()
lr=LogisticRegression()

# %%
models=[]
models.append(('KNeighborsClassifier',knc))
models.append(('SupportVectorClassifier',svc))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifierClassifier',adc))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gb))
models.append(('GradientBoostingClassifier',gbc))
models.append(('LogisticRegression',lr))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve,auc

# %%
#appling for loop for all the algorithms and also finding its respective roc_curve
Models=[]
score=[]
cvs=[]

rocscore=[]
for name,model in models:
    print('*****************',name,'**********************')
    print('\n')
    Models.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_val_score=',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds= roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    print('\n\n')
# Out:
# ***************** KNeighborsClassifier **********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8896457765667575
#
#
# Cross_val_score= 0.8811853769937603
#
#
# roc_auc_score= 0.6030572249804025
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       645
#            1       0.62      0.22      0.33        89
#
#     accuracy                           0.89       734
#    macro avg       0.76      0.60      0.64       734
# weighted avg       0.87      0.89      0.87       734
#
#
#
# [[633  12]
#  [ 69  20]]
# No handles with labels found to put in legend.
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
# ***************** SupportVectorClassifier **********************
#
#
# ...

# %%
result=pd.DataFrame({'Model':Models,'Accuracy_score':score,'Cross_val_score':cvs,'ROC':rocscore})
result
# Out:
#                           Model  Accuracy_score  Cross_val_score        ROC
# 0          KNeighborsClassifier       88.964578        88.118538  60.305722
# 1       SupportVectorClassifier       91.008174        91.659833  76.481143
# 2        RandomForestClassifier       95.640327        94.779540  83.959585
# 3  AdaBoostClassifierClassifier       90.463215        88.298898  69.875446
# 4        DecisionTreeClassifier       95.095368        94.239988  82.196673
# 5                    GaussianNB       88.147139        85.178562  69.041895
# 6    GradientBoostingClassifier       95.231608        93.819478  82.274192
# 7            LogisticRegression       88.555858        86.078294  60.073164

# %% [markdown]
# Observation:Here we see that decision tree classifier is giving best score. So we can finalize it as our model.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(dtc,'churn.pkl')
# Out:
# ['churn.pkl']
