# %% [markdown]
# Importing Modules or libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#reading csv file by using read_csv
df=pd.read_csv('database_IND.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding first 5 rows
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#                      geolocation_source  wepp_id year_of_capacity_data  \
# ...

# %%
#finding the number of rows and columns in the dataset
df.shape
# Out:
# (908, 25)

# %%
#finding datatype of each column
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %% [markdown]
# Observations: Here we observe that there are few object datatypes.

# %%
#statistical analysis of numerical attributes
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# ...

# %% [markdown]
# # # Preprocessing the data

# %%
#finding null values present in the dataset
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# Observation: Here we can see that there are null values present in different columns.

# %%
#visualizing null values
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: There are various columns which are entirely empty. So its better to drop that columns. As country and country_long is same.So, we can remove that columns.

# %%
df.drop(['wepp_id','estimated_generation_gwh','other_fuel2','other_fuel3','url','country','country_long','other_fuel1'],axis=1,inplace=True)
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 903                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 904  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 905  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 906                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 907       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel  commissioning_year  \
# 0      73.2407        Solar              2011.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    908 non-null    object
#  1   gppd_idnr               908 non-null    object
#  2   capacity_mw             908 non-null    float64
#  3   latitude                862 non-null    float64
#  4   longitude               862 non-null    float64
#  5   primary_fuel            908 non-null    object
#  6   commissioning_year      528 non-null    float64
#  7   owner                   342 non-null    object
#  8   source                  908 non-null    object
#  9   geolocation_source      889 non-null    object
#  10  year_of_capacity_data   520 non-null    float64
#  11  generation_gwh_2013     384 non-null    float64
#  12  generation_gwh_2014     401 non-null    float64
#  13  generation_gwh_2015     425 non-null    float64
# ...

# %%
#filling the null values for categorical data with their mode
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values = np.nan, strategy ='most_frequent')

# %%
df['generation_data_source']=imputer.fit_transform(df['generation_data_source'].values.reshape(-1,1))
df['commissioning_year']=imputer.fit_transform(df['commissioning_year'].values.reshape(-1,1))
df['owner']=imputer.fit_transform(df['owner'].values.reshape(-1,1))
df['latitude']=imputer.fit_transform(df['latitude'].values.reshape(-1,1))
df['longitude']=imputer.fit_transform(df['longitude'].values.reshape(-1,1))
df['geolocation_source']=imputer.fit_transform(df['geolocation_source'].values.reshape(-1,1))
df['year_of_capacity_data']=imputer.fit_transform(df['year_of_capacity_data'].values.reshape(-1,1))
df['generation_data_source']=imputer.fit_transform(df['generation_data_source'].values.reshape(-1,1))

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy ='mean') 
df['generation_gwh_2013']=imputer.fit_transform(df['generation_gwh_2013'].values.reshape(-1,1))
df['generation_gwh_2014']=imputer.fit_transform(df['generation_gwh_2014'].values.reshape(-1,1))
df['generation_gwh_2015']=imputer.fit_transform(df['generation_gwh_2015'].values.reshape(-1,1))
df['generation_gwh_2016']=imputer.fit_transform(df['generation_gwh_2016'].values.reshape(-1,1))
df['generation_gwh_2017']=imputer.fit_transform(df['generation_gwh_2017'].values.reshape(-1,1))

# %%
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 903                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 904  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 905  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 906                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 907       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel  commissioning_year  \
# 0      73.2407        Solar              2011.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    908 non-null    object
#  1   gppd_idnr               908 non-null    object
#  2   capacity_mw             908 non-null    float64
#  3   latitude                908 non-null    float64
#  4   longitude               908 non-null    float64
#  5   primary_fuel            908 non-null    object
#  6   commissioning_year      908 non-null    float64
#  7   owner                   908 non-null    object
#  8   source                  908 non-null    object
#  9   geolocation_source      908 non-null    object
#  10  year_of_capacity_data   908 non-null    float64
#  11  generation_gwh_2013     908 non-null    float64
#  12  generation_gwh_2014     908 non-null    float64
#  13  generation_gwh_2015     908 non-null    float64
# ...

# %% [markdown]
# # Univariable Analysis

# %%
#categorical attributes visualization
#data visualization by countplot

fig,ax = plt.subplots(2,3, figsize=(20,20))               # 'ax' has references to all the four axes
plt.suptitle("Distribution of various factors", fontsize=40)
sns.countplot(df['source'], ax = ax[0,0]) 
sns.countplot(df['generation_data_source'], ax = ax[0,1]) 
sns.countplot(df['primary_fuel'], ax = ax[0,2]) 
sns.countplot(df['owner'], ax = ax[1,0])
sns.countplot(df['year_of_capacity_data'], ax = ax[1,1])  
sns.countplot(df['geolocation_source'], ax = ax[1,2]) 
plt.xticks(rotation=30)
plt.subplots_adjust(bottom=0.3)
plt.show()

# %% [markdown]
# Observation: We get to know that columns such as year_of_capacity_data,generation_data_source has same values in entire column. so we can remove these columns.

# %%
df.drop(['generation_data_source','year_of_capacity_data'],axis=1,inplace=True)
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 903                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 904  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 905  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 906                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 907       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel  commissioning_year  \
# 0      73.2407        Solar              2011.0
# ...

# %%
df.corr()
# Out:
#                      capacity_mw  latitude  longitude  commissioning_year  \
# capacity_mw             1.000000  0.057801   0.217022            0.012518
# latitude                0.057801  1.000000   0.050511            0.035378
# longitude               0.217022  0.050511   1.000000           -0.138390
# commissioning_year      0.012518  0.035378  -0.138390            1.000000
# generation_gwh_2013     0.667842  0.038629   0.020367            0.094530
# generation_gwh_2014     0.705434  0.045992   0.017902            0.114534
# generation_gwh_2015     0.722081  0.038428   0.026353            0.127325
# generation_gwh_2016     0.752829  0.033436   0.046857            0.147275
# generation_gwh_2017     0.767040  0.033892   0.049855            0.147874
#
#                      generation_gwh_2013  generation_gwh_2014  \
# capacity_mw                     0.667842             0.705434
# latitude                        0.038629             0.045992
# ...

# %%
#visualization of correlation by using heatmap
plt.subplots(figsize=(18, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation: on observing the above heatmap we get to know that comissioning year is very less correlated with capacity_mw.

# %%
#visualization all the columns with each other
sns.pairplot(df)

# %% [markdown]
# Observation: Here we observed that data is skewed.

# %%
df.drop(['commissioning_year'],axis=1,inplace=True)
df
# Out:
#                              name   gppd_idnr  capacity_mw  latitude  \
# 0                ACME Solar Tower  WRI1020239          2.5   28.1839
# 1             ADITYA CEMENT WORKS  WRI1019881         98.0   24.7663
# 2        AES Saurashtra Windfarms  WRI1026669         39.2   21.9038
# 3                     AGARTALA GT  IND0000001        135.0   23.8712
# 4                    AKALTARA TPP  IND0000002       1800.0   21.9603
# ..                            ...         ...          ...       ...
# 903                  YERMARUS TPP  IND0000513       1600.0   16.2949
# 904  Yelesandra Solar Power Plant  WRI1026222          3.0   12.8932
# 905  Yelisirur wind power project  WRI1026776         25.5   15.2758
# 906                   ZAWAR MINES  WRI1019901         80.0   24.3500
# 907       iEnergy Theni Wind Farm  WRI1026761         16.5    9.9344
#
#      longitude primary_fuel                                owner  \
# 0      73.2407        Solar                          Solar Paces
# ...

# %%
#transforming the non-numeric data to numeric data by using label encoder
from sklearn.preprocessing import LabelEncoder

for col in df.columns:
    if df[col].dtype==np.number:
        continue
    df[col]=LabelEncoder().fit_transform(df[col])

# %%
df
# Out:
#      name  gppd_idnr  capacity_mw  latitude  longitude  primary_fuel  owner  \
# 0       0        658          2.5   28.1839    73.2407             6    229
# 1       1        520         98.0   24.7663    74.6090             1    258
# 2       2        854         39.2   21.9038    69.3732             7      2
# 3       3          0        135.0   23.8712    91.3602             2      5
# 4       4          1       1800.0   21.9603    82.4091             1      5
# ..    ...        ...          ...       ...        ...           ...    ...
# 903   903        494       1600.0   16.2949    77.3568             1      5
# 904   904        823          3.0   12.8932    78.1654             6    114
# 905   905        892         25.5   15.2758    75.5811             7      5
# 906   906        540         80.0   24.3500    73.7477             1     91
# 907   907        877         16.5    9.9344    77.4768             7    279
#
# ...

# %%
#dividing the data into dependent and independent variable
x=df.drop(columns=['primary_fuel'],axis=1)
y=df['primary_fuel']

# %%
#nomalizing the curve
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x=scale.fit_transform(x)

# %%
#importing models and metrics from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#finding best randomstate for train test split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=accuracy_score(y_test,y_pred)
        print("accuracy score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max accuracy score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
#finding best random state
from sklearn.linear_model import LogisticRegression
regr=LogisticRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# accuracy score corresponding to 42 is 0.7417582417582418
# accuracy score corresponding to 43 is 0.8021978021978022
# accuracy score corresponding to 44 is 0.7747252747252747
# accuracy score corresponding to 45 is 0.7307692307692307
# accuracy score corresponding to 46 is 0.7747252747252747
# accuracy score corresponding to 47 is 0.7527472527472527
# accuracy score corresponding to 48 is 0.7802197802197802
# accuracy score corresponding to 49 is 0.7802197802197802
# accuracy score corresponding to 50 is 0.7802197802197802
# accuracy score corresponding to 51 is 0.7582417582417582
# accuracy score corresponding to 52 is 0.7802197802197802
# accuracy score corresponding to 53 is 0.7582417582417582
# accuracy score corresponding to 54 is 0.8406593406593407
# accuracy score corresponding to 55 is 0.7637362637362637
# accuracy score corresponding to 56 is 0.7582417582417582
# accuracy score corresponding to 57 is 0.7417582417582418
# ...

# %%
#dividing the data into train and test by using train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=54)

# %%
#Importing models for classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Hyperparameter tunning by using GridSearchCV

# %%
#parameters for knn
neighbors={"n_neighbors":range(1,20)}
knc=KNeighborsClassifier()
gknc=GridSearchCV(knc,neighbors,cv=10)
gknc.fit(x,y)
gknc.best_params_
# Out:
# {'n_neighbors': 8}

# %%
#parameters for random forest
rfc = RandomForestClassifier()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfc, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'auto',
#  'min_samples_split': 4,
#  'n_estimators': 20}

# %%
#best parameters for AdaBoostClassifier
n_estimators={"n_estimators":range(1,25)}
adc=AdaBoostClassifier()
gadc=GridSearchCV(adc,n_estimators,cv=10)
gadc.fit(x,y)
gadc.best_params_
# Out:
# {'n_estimators': 6}

# %%
#best parameters for decisiontreeclassifier
param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
dtc=DecisionTreeClassifier()    
gdtc=GridSearchCV(dtc, param_grid, cv=5)
gdtc.fit(x, y)
gdtc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 13}

# %%
#best parameters for support vector classifier
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svc=SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.784141825025803
# rbf
# {'C': 10, 'kernel': 'rbf'}

# %%
#best parameter for gradiantboosting classifier
n_estimators={"n_estimators":range(1,25)}
gbc=GradientBoostingClassifier()
gc=GridSearchCV(gbc,n_estimators,cv=10)
gc.fit(x,y)
gc.best_params_
# Out:
# {'n_estimators': 24}

# %%
#fitting best parameters
knc=KNeighborsClassifier(n_neighbors=8)
svc=SVC(C= 10, kernel='rbf')
dtc=DecisionTreeClassifier(criterion='entropy', max_depth=13)
rfc=RandomForestClassifier(bootstrap= True, max_features='auto',min_samples_split= 4,n_estimators=20)
adc=AdaBoostClassifier(n_estimators=6)
gbc=GradientBoostingClassifier(n_estimators=24)
gb=GaussianNB()
lr=LogisticRegression()

# %%
models=[]
models.append(('KNeighborsClassifier',knc))
models.append(('SupportVectorClassifier',svc))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifierClassifier',adc))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gb))
models.append(('GradientBoostingClassifier',gbc))
models.append(('LogisticRegression',lr))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve,auc

# %%
#appling for loop for all the algorithms and also finding its respective roc_curve
Models=[]
score=[]
cvs=[]

rocscore=[]
for name,model in models:
    print('*****************',name,'**********************')
    print('\n')
    Models.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_val_score=',sc)
    cvs.append(sc*100)
# Out:
# ***************** KNeighborsClassifier **********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.82
#
#
# Cross_val_score= 0.7642857142857142
# ***************** SupportVectorClassifier **********************
#
#
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
#
# Accuracy_score= 0.87
#
#
# Cross_val_score= 0.7917826617826618
# ***************** RandomForestClassifier **********************
#
#
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
# ...

# %%
result=pd.DataFrame({'Model':Models,'Accuracy_score':score,'Cross_val_score':cvs})
result
# Out:
#                           Model  Accuracy_score  Cross_val_score
# 0          KNeighborsClassifier            82.0        76.428571
# 1       SupportVectorClassifier            87.0        79.178266
# 2        RandomForestClassifier            89.0        82.378510
# 3  AdaBoostClassifierClassifier            69.5        58.487179
# 4        DecisionTreeClassifier            82.0        78.307692
# 5                    GaussianNB            69.5        60.233211
# 6    GradientBoostingClassifier            89.0        78.617827
# 7            LogisticRegression            83.5        76.537241

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(rfc,'fuel.pkl')
# Out:
# ['fuel.pkl']

# %% [markdown]
# # Case2: when we need to predict capacity_mw

# %%
#dividing the data into dependent and independent variable
x1=df.drop(columns=['capacity_mw'],axis=1)
y1=df['capacity_mw']

# %%
#nomalizing the curve
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x1=scale.fit_transform(x1)

# %%
#Here we will find out the random state value with which our linear model will learn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
#finding best randomstate for train test split
def maxr2_score(regr,a,b):
    max_r_score=0
    for r_state in range(42,100):
        x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,random_state=r_state,test_size=0.20)
        regr.fit(x1_train,y1_train)
        y1_pred=regr.predict(x1_test)
        r2_scr=r2_score(y1_test,y1_pred)
        print("r2 score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
r_state=maxr2_score(regr,x1,y1)
# Out:
# r2 score corresponding to 42 is 0.8022087245407492
# r2 score corresponding to 43 is 0.7933498557160736
# r2 score corresponding to 44 is 0.5587729139528952
# r2 score corresponding to 45 is 0.524154164461927
# r2 score corresponding to 46 is 0.708220805563731
# r2 score corresponding to 47 is 0.6858735559190998
# r2 score corresponding to 48 is 0.7389608819944826
# r2 score corresponding to 49 is 0.7838690020554858
# r2 score corresponding to 50 is 0.7972658157229215
# r2 score corresponding to 51 is 0.7671129445689726
# r2 score corresponding to 52 is 0.7012153194436355
# r2 score corresponding to 53 is 0.7839733399063156
# r2 score corresponding to 54 is 0.7409715315658485
# r2 score corresponding to 55 is 0.7151192688711875
# r2 score corresponding to 56 is 0.6386065112662135
# r2 score corresponding to 57 is 0.7162660469028146
# r2 score corresponding to 58 is 0.6593794624140594
# r2 score corresponding to 59 is 0.6157933949582113
# ...

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,random_state=81,test_size=0.20)

# %%
#lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Hyperparameter tunning by using grid search cv

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x1,y1)
gknr.best_params_
# Out:
# {'n_neighbors': 5}

# %%
#importing regression alogorithms from sklearn
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
#finding best parameter for ridge by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
rg=Ridge()
grg=GridSearchCV(rg,param_grid=alphavalue)
grg.fit(x1,y1)
grg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for lasso by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
las=Lasso()
lasg=GridSearchCV(las,param_grid=alphavalue)
lasg.fit(x1,y1)
lasg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for randomforest by using grid search cv
rfr = RandomForestRegressor()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfr, param_grid, n_jobs=-1, cv=5)

grid.fit(x1, y1)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'sqrt',
#  'min_samples_split': 4,
#  'n_estimators': 20}

# %%
#finding best parameters for support vector regressor by using grid search cv
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x1,y1)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.7185382797320988
# linear
# {'C': 10, 'kernel': 'linear'}

# %%
#finding best parameter for decision tree regressor by using grid search cv
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x1,y1)
grid_cv_dtm.best_params_
# Out:
# {'criterion': 'mae',
#  'max_depth': 6,
#  'max_leaf_nodes': 100,
#  'min_samples_leaf': 20,
#  'min_samples_split': 20}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,25)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x1,y1)
gad.best_params_
# Out:
# {'n_estimators': 9}

# %%
#fitting parameters in our algorithms
knr=KNeighborsRegressor(n_neighbors=5)
rg=Ridge(alpha=1)
las=Lasso(alpha=1)
svr=SVR(C= 10, kernel= 'linear')
lr=LinearRegression(normalize=True)
dtr=DecisionTreeRegressor(criterion= 'mae', max_depth= 6, max_leaf_nodes= 100, min_samples_leaf= 20, min_samples_split= 20)
rfr=RandomForestRegressor(bootstrap= True, max_features='sqrt',min_samples_split= 4,n_estimators=20)
ad=AdaBoostRegressor(n_estimators=9)

# %%
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('Ridge',rg))
models.append(('Lasso',las))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
#for loop for all the algorithms along with their cross validation
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score=',sc)
    sc1=sc*100
    cvs.append(sc1)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')
#
#
# score: 0.8891832277362464
# mean squared error 0.7062
# mean absolute error 0.467
# r2_score 0.8612573673870334
#
#
# Cross_Val_Score= 0.7737062637269865
#
#
# ************ Ridge ************
#
#
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)
#
#
# score: 0.6060706491650535
# mean squared error 1.8495433697725434
# mean absolute error 1.0734201409670592
# r2_score 0.6366319509287734
#
#
# Cross_Val_Score= 0.5561386118471155
#
#
# ************ Lasso ************
#
#
# Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':sco,'r2score':r2score,'Cross_val_score':cvs})
result
# Out:
#                    Model  Accuracy_score    r2score  Cross_val_score
# 0    KNeighborsRegressor        0.889183  86.125737        77.370626
# 1                  Ridge        0.606071  63.663195        55.613861
# 2                  Lasso        0.145924  15.704366        10.620720
# 3   SupportVectorMachine        0.859307  83.405780        78.284599
# 4        LinearRegressor        0.606075  63.661323        55.595533
# 5  DecisionTreeRegressor        0.857892  83.005894        82.679668
# 6  RandomForestRegressor        0.975441  90.268427        88.144912
# 7      AdaBoostRegressor        0.906080  88.551157        84.515365

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(rfr,'capacity.pkl')
# Out:
# ['capacity.pkl']
