# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#reading csv file by using read_csv and converting '?' into NaN values
df=pd.read_csv("heartdisease_data.csv",na_values=["?"])

# %%
#Exploratory data Analysis
#adding column names in the dataset
df.columns =['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      NaN NaN   NaN    0
# ...

# %%
#finding shape of dataset
df.shape
# Out:
# (199, 14)

# %% [markdown]
# Here, there are 199 rows and 14 columns present in the dataset

# %%
#finding first five rows
df.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1   60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2   55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3   66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4   66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
#
#    slope  ca  thal  num
# 0    NaN NaN   NaN    0
# 1    3.0 NaN   NaN    2
# 2    1.0 NaN   NaN    1
# 3    2.0 NaN   NaN    0
# 4    1.0 NaN   NaN    0

# %%
#finding last five rows
df.tail()
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 194    NaN NaN   NaN    1
# 195    NaN NaN   NaN    0
# 196    NaN NaN   6.0    2
# 197    NaN NaN   NaN    0
# 198    NaN NaN   NaN    1

# %%
#finding unique values present in each column
df.nunique()
# Out:
# age         39
# sex          2
# cp           4
# trestbps    40
# chol        99
# fbs          2
# restecg      3
# thalach     59
# exang        2
# oldpeak     14
# slope        3
# ca           1
# thal         3
# num          5
# dtype: int64

# %% [markdown]
# Observation: Here we can say that columns like sex,cp,fbs,restecg,exang,slope,ca,thal,num has categorical data

# %%
#finding datatypes of each column
df.dtypes
#all the data is in int and float type
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg       int64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# num           int64
# dtype: object

# %%
#finding null values
df.isnull().sum()
# Out:
# age           0
# sex           0
# cp            0
# trestbps     56
# chol          7
# fbs           7
# restecg       0
# thalach      53
# exang        53
# oldpeak      56
# slope       102
# ca          197
# thal        165
# num           0
# dtype: int64

# %% [markdown]
# Observation: Here we find that many values in different column are missing.There are maximum missing values present in column ca and thal

# %%
#Visualizing null value by using heatmap
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: Here we can see that ca has no values. So we can drop that column as it make no use here.

# %%
#finding statistical inference
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  143.000000  192.000000  192.000000
# mean    59.331658    0.969849    3.502513  133.720280  178.322917    0.354167
# std      7.827080    0.171433    0.796928   21.607056  114.181310    0.479510
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  148.000000  256.500000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope   ca  \
# count  199.000000  146.000000  146.000000  143.000000  97.000000  2.0
# mean     0.733668  122.869863    0.643836    1.309091   2.134021  0.0
# ...

# %% [markdown]
# Observation: Here we can get min age is 35 and max age is 77. Average age of people having disease are of 60 years.
#             Average colestrol of people is 178.
#             In thal 25% data and 100% data is same. This show that there are many values missing in this column. So it will not give accurate results. Its better to drop that column.

# %% [markdown]
# # Visualization of Data

# %%
#Visualizing data by using boxplot
for i in df.describe().columns:
    sns.boxplot(df[i].dropna())
    plt.show()

# %% [markdown]
# Observation: Here we can visualize the median values of the data. We can see that median cholestrol level is aprrox 220.
#              thalch is having a median value of 120.

# %%
#Data Wrangling
#Replacing NaN values by using SimpleImputer function of sklearn library
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values = np.nan, strategy ='median')

# %%
df['trestbps']=imputer.fit_transform(df['trestbps'].values.reshape(-1,1))

# %% [markdown]
# Observation: By visualizing the boxplot we are getting an idea that missing value in threstbps,thalach,oldpeak,slope,chol can be replaced by median values. Because it gives average value which is best fitted for the people having such situation.

# %%
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1     130.0  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4     130.0  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      NaN NaN   NaN    0
# ...

# %%
df['thalach']=imputer.fit_transform(df['thalach'].values.reshape(-1,1))

# %%
df['oldpeak']=imputer.fit_transform(df['oldpeak'].values.reshape(-1,1))

# %%
df['slope']=imputer.fit_transform(df['slope'].values.reshape(-1,1))

# %%
df['chol']=imputer.fit_transform(df['chol'].values.reshape(-1,1))

# %%
#replacing null values with most frequent number using Simple Imputer function
imputer = SimpleImputer(missing_values = np.nan, strategy ='most_frequent')

# %% [markdown]
# Observation: Here missing values are replaced by most frequent numbers which means the stage which is most common among the people having such situation.

# %%
df['fbs']=imputer.fit_transform(df['fbs'].values.reshape(-1,1))

# %%
df['exang']=imputer.fit_transform(df['exang'].values.reshape(-1,1))

# %%
#verifying changes in the dataset
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1     130.0  139.0  0.0        1    120.0    1.0      1.5
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4     130.0  385.0  1.0        2    120.0    1.0      1.5
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      2.0 NaN   NaN    0
# ...

# %%
#As column ca and thal having maximum values missing.So we can drop these columns from the dataset.
df.drop(['ca','thal'],axis=1,inplace=True)

# %%
#verifying changes in the data
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1     130.0  139.0  0.0        1    120.0    1.0      1.5
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4     130.0  385.0  1.0        2    120.0    1.0      1.5
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  num
# 0      2.0    0
# 1      3.0    2
# 2      1.0    1
# ...

# %%
#verifying null values present in the data
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# num         0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
#data visualization by countplot

fig,ax = plt.subplots(2,3, figsize=(20,20))               # 'ax' has references to all the four axes
plt.suptitle("Distribution of various factors", fontsize=40)
sns.countplot(df['sex'], ax = ax[0,0]) 
sns.countplot(df['cp'], ax = ax[0,1]) 
sns.countplot(df['restecg'], ax = ax[0,2]) 
sns.countplot(df['exang'], ax = ax[1,0])
sns.countplot(df['slope'], ax = ax[1,1])  
sns.countplot(df['num'], ax = ax[1,2]) 
plt.xticks(rotation=30)
plt.subplots_adjust(bottom=0.3)
plt.show()

# %% [markdown]
# Observation: sex: Number of females are less as compare to males.
#
#    Chestpaintype(cp): 1:typical anginal, 2:atypical anginal, 3:non-anginal pain  4: asympotic
#                Here we observe that sympotic is more in number whereas typical anginal is less type among the people.
#
#    Resting ECG(restecg): There are three categories in it 0 -> Normal  1-> having STT wave abnormal 2->Left ventrical
#                  Here we observe that maximum people having STT wave abnormal and very less people having problem in left     ventrical.
#
#    Exercise induced angina(exang): 1-> yes   0 -> No
#                 Here we observe that in many people exercise induced angina.
#
#     Slope : ST depression induced by exercise relative to rest. Peak exercise St segment. 1->upsloping 2-> flat 3->downsloping
#         Here we observe that due to ST depression maximum people suffering from a slope between 2 and 3.
#
#   Diagnosis of heart disease(num): 0-> absent, 1,2,3,4->present
#   Here we observe that approx(50) people have no disease. However 149(approx) people are suffering from disease.

# %% [markdown]
# # Bivariate Analysis

# %%
#Now let us visualize that how 
plt.subplots(figsize=(12,4))
sns.countplot(x='num',hue='sex',data=df)

# %% [raw]
# Observation: Here 0-> Female  1->male
# We observe that more males are suffering from heart disease as compare to females.

# %%
df['num'].value_counts()

#There are 51 people having no disease where 148 people are suffering from disease.
# Out:
# 1    56
# 0    51
# 3    42
# 2    40
# 4    10
# Name: num, dtype: int64

# %%
#visualizing relation between sex, age and disease
sns.catplot(data=df,x='sex',y='age',hue='num')

# %% [markdown]
# Observation: Here we observe that in males the minimum age for disease is approx 38 where in female the disease start at an age of approx 55. In male, there are different level of heart disease condition. While in female there is only one level. That means males are facing more complex problems with respect to disease.

# %%
#Visualizing relation between sex, chol and disease
sns.barplot(data=df,x='sex',y='chol',hue='num')

# %% [markdown]
# Observation: Here we observe that
#
#     Female with No disease : Cholestrol Level: 180(approx)
#     Male with no disease:   cholestrol level: 170(approx)
#
#     Female with disease: cholestrol Level: 290(approx)
#     Male with disease:  cholestrol Level:200(approx)
#
#     This shows that in female having disease the rate of cholestrol is high.

# %%
#visualization between sex, slope and disease
sns.barplot(data=df,x='sex',y='slope',hue='num')

# %% [markdown]
# Observation:Here we observe that
#
#     female having no disease :  slope=1.5                      female having disease: slope=2
#     2 is the maximum slope in the female.
#
#     Male having no disease: slope= 2                           Male having disease: slope varies between 2 to 2.5

# %%
#finding correlation between columns
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.033837 -0.039809  0.178798  0.068398  0.137672
# sex       0.033837  1.000000  0.037525  0.008081 -0.094682 -0.058846
# cp       -0.039809  0.037525  1.000000  0.093007  0.066678 -0.042263
# trestbps  0.178798  0.008081  0.093007  1.000000  0.141412  0.186838
# chol      0.068398 -0.094682  0.066678  0.141412  1.000000  0.178284
# fbs       0.137672 -0.058846 -0.042263  0.186838  0.178284  1.000000
# restecg   0.001487  0.060305  0.033617  0.088162  0.027390  0.172306
# thalach  -0.149078 -0.003687 -0.107093 -0.004188 -0.042937  0.031356
# exang     0.127815  0.028906  0.088211  0.172243  0.114268 -0.174385
# oldpeak   0.153355  0.099947  0.010277  0.100467  0.009586 -0.091554
# slope     0.107525  0.086842  0.059955  0.089200  0.042223 -0.009947
# num       0.286630  0.147190  0.167202  0.144768  0.078244  0.050448
#
#            restecg   thalach     exang   oldpeak     slope       num
# ...

# %%
#visualization of correlation by using heatmap
plt.subplots(figsize=(18, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation: Here we observe that age, oldpeak is more correlated with other columns.

# %%
#visualization all the columns with each other
sns.pairplot(df)

# %%
#Here the disease is categories into different levels. Let us divide it into two levels of having or not having disease by using lanbda function
df['num']=df['num'].apply(lambda x: '1' if x>0 else '0')
df
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1     130.0  139.0  0.0        1    120.0    1.0      1.5
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4     130.0  385.0  1.0        2    120.0    1.0      1.5
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope num
# 0      2.0   0
# 1      3.0   1
# 2      1.0   1
# ...

# %%
#splitting the data
x=df.iloc[:,0:-1]
x
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1     130.0  139.0  0.0        1    120.0    1.0      1.5
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4     130.0  385.0  1.0        2    120.0    1.0      1.5
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope
# 0      2.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      1.0
# ...

# %%
#target column
y=df.iloc[:,-1]
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 194    1
# 195    0
# 196    1
# 197    0
# 198    1
# Name: num, Length: 199, dtype: object

# %%
#importing models and metrics from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
#finding best randomstate for train test split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=accuracy_score(y_test,y_pred)
        print("accuracy score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max accuracy score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
#finding best random state
from sklearn.linear_model import LogisticRegression
regr=LogisticRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# accuracy score corresponding to 42 is 0.825
# accuracy score corresponding to 43 is 0.675
# accuracy score corresponding to 44 is 0.8
# accuracy score corresponding to 45 is 0.775
# accuracy score corresponding to 46 is 0.775
# accuracy score corresponding to 47 is 0.875
# accuracy score corresponding to 48 is 0.75
# accuracy score corresponding to 49 is 0.65
# accuracy score corresponding to 50 is 0.8
# accuracy score corresponding to 51 is 0.75
# accuracy score corresponding to 52 is 0.65
# accuracy score corresponding to 53 is 0.65
# accuracy score corresponding to 54 is 0.8
# accuracy score corresponding to 55 is 0.65
# accuracy score corresponding to 56 is 0.65
# accuracy score corresponding to 57 is 0.725
# accuracy score corresponding to 58 is 0.65
# accuracy score corresponding to 59 is 0.675
# accuracy score corresponding to 60 is 0.75
# accuracy score corresponding to 61 is 0.75
# accuracy score corresponding to 62 is 0.675
# accuracy score corresponding to 63 is 0.675
# ...

# %%
#dividing the data into train and test by using train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=47)

# %%
#Importing models for classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Hyperparameter tunning by using GridSearchCV

# %%
#parameters for knn
neighbors={"n_neighbors":range(1,20)}
knc=KNeighborsClassifier()
gknc=GridSearchCV(knc,neighbors,cv=10)
gknc.fit(x,y)
gknc.best_params_
# Out:
# {'n_neighbors': 8}

# %%
#parameters for random forest
rfc = RandomForestClassifier()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfc, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'sqrt',
#  'min_samples_split': 8,
#  'n_estimators': 20}

# %%
#best parameters for AdaBoostClassifier
n_estimators={"n_estimators":range(1,25)}
adc=AdaBoostClassifier()
gadc=GridSearchCV(adc,n_estimators,cv=10)
gadc.fit(x,y)
gadc.best_params_
# Out:
# {'n_estimators': 3}

# %%
#best parameters for decisiontreeclassifier
param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
dtc=DecisionTreeClassifier()    
gdtc=GridSearchCV(dtc, param_grid, cv=5)
gdtc.fit(x, y)
gdtc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 3}

# %%
#best parameters for support vector classifier
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svc=SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.7487179487179487
# rbf
# {'C': 1, 'kernel': 'rbf'}

# %%
#best parameter for gradiantboosting classifier
n_estimators={"n_estimators":range(1,25)}
gbc=GradientBoostingClassifier()
gc=GridSearchCV(gbc,n_estimators,cv=10)
gc.fit(x,y)
gc.best_params_
# Out:
# {'n_estimators': 5}

# %%
#fitting best parameters
knc=KNeighborsClassifier(n_neighbors=8)
svc=SVC(C= 1, kernel='rbf')
dtc=DecisionTreeClassifier(criterion='entropy', max_depth=3)
rfc=RandomForestClassifier(bootstrap= True, max_features='sqrt',min_samples_split= 8,n_estimators=20)
adc=AdaBoostClassifier(n_estimators=3)
gbc=GradientBoostingClassifier(n_estimators=5)
gb=GaussianNB()
lr=LogisticRegression()

# %%
#building different models
models=[]
models.append(('KNeighborsClassifier',knc))
models.append(('SupportVectorClassifier',svc))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifierClassifier',adc))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gb))
models.append(('GradientBoostingClassifier',gbc))
models.append(('LogisticRegression',lr))

# %%
#importing models for cross_val_score, roc_curve,auc
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve,auc

# %%
#applying for looping to run all the models in one go
Models=[]
score=[]
cvs=[]


for name,model in models:
    print('*****************',name,'**********************')
    print('\n')
    Models.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_val_score=',sc)
    cvs.append(sc*100)
    print('\n')    
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
# Out:
# ***************** KNeighborsClassifier **********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.7727272727272727
#
#
# Cross_val_score= 0.7981578947368422
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.44      0.44      0.44         9
#            1       0.86      0.86      0.86        35
#
#     accuracy                           0.77        44
#    macro avg       0.65      0.65      0.65        44
# weighted avg       0.77      0.77      0.77        44
#
#
#
# [[ 4  5]
#  [ 5 30]]
#
#
# ***************** SupportVectorClassifier **********************
#
#
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
# ...

# %%
result=pd.DataFrame({'Model':Models,'Accuracy_score':score,'Cross_val_score':cvs})
result
# Out:
#                           Model  Accuracy_score  Cross_val_score
# 0          KNeighborsClassifier       77.272727        79.815789
# 1       SupportVectorClassifier       81.818182        74.815789
# 2        RandomForestClassifier       84.090909        74.342105
# 3  AdaBoostClassifierClassifier       81.818182        75.868421
# 4        DecisionTreeClassifier       72.727273        72.315789
# 5                    GaussianNB       84.090909        75.815789
# 6    GradientBoostingClassifier       79.545455        74.868421
# 7            LogisticRegression       86.363636        74.289474

# %% [markdown]
# Observation: Here we observed that Logistic regression is giving maximum accuracy_score i.e 86.36 as compare to others. So, we can finalize logisticRegression as the final model.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(lr,'heart.pkl')
# Out:
# ['heart.pkl']
