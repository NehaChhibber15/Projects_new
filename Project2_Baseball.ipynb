# %%
#importing libraries required to to apply operations on dataset and visualization purpose
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Uploading dataset file and read it by using read_csv command
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding rows and columns in a data set
df.shape
# Out:
# (30, 17)

# %%
#finding columns present in the dataset
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#finding first 10 rows
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
#finding data type of each column
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#finding null values in the dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Observation: Here, we observe that there is no null value present in the dataset.

# %%
#checking whether the null value is present or not
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: Here we visualize that there is no null value present in the dataset.

# %%
#finding statistic inference
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Observation: Here we visualize the min, max and average of each column.

# %%
#finding correlation between different attributes present in the dataset
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#visualizing correlation by using heatmap
plt.subplots(figsize=(15, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation: On observing the given heatmap we get to know that Wins is very less or negatively correlated with ERA(Earned Run Average), ER(Earned Runs), RA(Runs Allowed), 3B(Triples). However, it is very highly correlated with R(Runs), 2B(Doubles), HR(Homeruns),BB(Walks),SHO(Shutouts),SV(Saves).

# %%
#removing outliers from the dataset
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#removing z values which are more than 3. because threshold= 3 is settled above
df1=df[(z<3).all(axis=1)]

# %%
 #here we get the new data frame in which 1 row is deleted
df1.shape
# Out:
# (29, 17)

# %%
#dividing the data into independent and dependent variable
x=df1.iloc[:,1:17]
y=df1.iloc[:,0]

# %%
#univariable analysis
#visualizing distplot of each column
for i in df1.describe().columns:
    sns.distplot(df1[i])
    plt.show()

# %% [markdown]
# Observation: Here we can see that we transformed that data in normalize form.

# %%
#Visualizing data by using boxplot
for i in df1.describe().columns:
    sns.boxplot(df1[i])
    plt.show()

# %% [markdown]
# Observation: Average wins is between 80 and 85.
#              Average runs are between 675 and 700.
#              Average house runs are of 1375.
#              Average double are of 2B.
#              Average of 3B are 33.
#              Here we are getting an idea of min, max and average values.

# %%
#let us find out which feature is more correlated by using extra tree classifier.
#feature importance
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
#finding correlation of each feature
print(model.feature_importances_)
# Out:
# [0.05790371 0.06819083 0.0621794  0.07755049 0.0553203  0.05533939
#  0.05378822 0.04707329 0.08499393 0.06969656 0.05215041 0.04895693
#  0.05905884 0.05683803 0.06667099 0.08428868]

# %%
ranked_features=pd.Series(model.feature_importances_,index=x.columns)
ranked_features.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# Observation:Here we can observe that 3B, SV, SHO are least correlated.

# %%
x=x.drop(columns=['BB','SO','CG','HR','ERA'])
#Here BB,SO,CG are the least correlated coloumns where 3B and E are similarly correlated columns. So we can drop these columns to make or machine learning in better way.

# %%
x
# Out:
#       R    AB     H   2B  3B   SB   RA   ER  SHO  SV    E
# 0   724  5575  1497  300  42  104  641  601    8  56   88
# 1   696  5467  1349  277  44   70  700  653   12  45   86
# 2   669  5439  1395  303  29   86  640  584   10  38   79
# 3   622  5533  1381  260  27   68  701  643    9  37  101
# 4   689  5605  1515  289  49   83  803  746   12  35   86
# 6   764  5567  1397  272  19   63  698  652    4  48   93
# 7   713  5485  1370  246  20   44  693  646   10  43   77
# 8   644  5485  1383  278  32   87  642  604   12  60   95
# 9   748  5640  1495  294  33   71  753  694   10  40   97
# 10  751  5511  1419  279  32  101  733  680    9  45  119
# 11  729  5459  1363  278  26  121  618  572   13  39   85
# 12  661  5417  1331  243  21   52  675  630   12  46   93
# 13  656  5544  1379  262  22   69  726  677   12  45   94
# 14  694  5600  1405  277  46   78  729  664   15  28  126
# 15  647  5484  1386  288  39   69  525  478   15  62   96
# ...

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# SB     0.494966
# RA     0.018155
# ER     0.018461
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#transforming the data by using standardScaler
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
#Here we will find out the random state value with which our linear model will learn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
max_r_score=0
for r_state in range(42,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max_r2_score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max_r2_score corresponding to 195 is 0.9709755127079431

# %%
#Lets use cross val score function to check above is overfitting or not
from sklearn.model_selection import cross_val_score
a_score=cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
a_score
# Out:
# 0.2498482641460186

# %%
#Let us try other model for regression also by using hyperparameter tunning and grid search
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=195,test_size=0.20)

# %%
#lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Hyperparameter tunning by using Grid Search CV

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 3}

# %%
#importing algorithms
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
#finding best parameter for ridge
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
rg=Ridge()
grg=GridSearchCV(rg,param_grid=alphavalue)
grg.fit(x,y)
grg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for lasso
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
las=Lasso()
lasg=GridSearchCV(las,param_grid=alphavalue)
lasg.fit(x,y)
lasg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for randomforestregressor
rfr = RandomForestRegressor()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfr, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'sqrt',
#  'min_samples_split': 8,
#  'n_estimators': 20}

# %%
#finding best parameter for SVR
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.3885720356498849
# linear
# {'C': 10, 'kernel': 'linear'}

# %%
#finding best parameter for DecisionTreeRegressor
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x,y)
grid_cv_dtm.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 2,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 20,
#  'min_samples_split': 10}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,25)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x,y)
gad.best_params_
# Out:
# {'n_estimators': 22}

# %% [markdown]
# # Finding Best Model

# %%
knr=KNeighborsRegressor(n_neighbors=3)
rg=Ridge(alpha=1)
las=Lasso(alpha=1)
svr=SVR(C= 10, kernel= 'linear')
lr=LinearRegression()
dtr=DecisionTreeRegressor(criterion= 'mse', max_depth= 2, max_leaf_nodes= 5, min_samples_leaf= 20, min_samples_split= 10)
rfr=RandomForestRegressor(bootstrap= True, max_features='sqrt',min_samples_split= 8,n_estimators=20)
ad=AdaBoostRegressor(n_estimators=7)

# %%
#creating model for algorithm
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('Ridge',rg))
models.append(('Lasso',las))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
#importing metrics for finding error
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
#applying for loop on all the algorithm
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score=',sc)
    sc1=sc*100
    cvs.append(sc1)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')
#
#
# score: 0.6979707993071023
# mean squared error 78.18518518518518
# mean absolute error 8.444444444444443
# r2_score 0.6055680119581466
#
#
# Cross_Val_Score= -3.9875012219720505
#
#
# ************ Ridge ************
#
#
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)
#
#
# score: 0.863577417160014
# mean squared error 7.922713397057957
# mean absolute error 2.1174976744341243
# r2_score 0.9600311543870395
#
#
# Cross_Val_Score= -3.6861876308952715
#
#
# ************ Lasso ************
#
#
# Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
# ...

# %%
result=pd.DataFrame({'Model':Model,'score':sco,'R2_score':r2score})
result
# Out:
#                    Model     score   R2_score
# 0    KNeighborsRegressor  0.697971  60.556801
# 1                  Ridge  0.863577  96.003115
# 2                  Lasso  0.809960  92.726778
# 3   SupportVectorMachine  0.808455  95.879291
# 4        LinearRegressor  0.876841  97.097551
# 5  DecisionTreeRegressor  0.000000  -3.587444
# 6  RandomForestRegressor  0.815947  61.627678
# 7      AdaBoostRegressor  0.942233  77.918302

# %% [markdown]
# Observation: Here we observe that Linear Regression is giving best R2 score. So we can finalize this as our final model.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(lr,'Baseball,pkl')
# Out:
# ['Baseball,pkl']
