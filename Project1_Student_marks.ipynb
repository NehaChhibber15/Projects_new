# %%
#installing mysql connector
# !pip install mysql-connector-python

# %%
#imported connector to connect mysql with jupyternotebook
import mysql.connector

# %%
#settling parameters in the notebook
import pandas as pd
con=mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='neha15',
    database='neha')
df=pd.read_sql_query("Select * from student3",con)
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    Suresh      M  1987-05-04     75       96         78       64       90
# 1    Ramesh      M  1989-05-25     25       54         89       76       95
# 2   Jessica      F  1990-08-12     78       96         86       63       54
# 3  Jennifer      F  1989-09-02     58       96         78       46       96
# 4      Annu      F  1988-04-05     45       87         52       89       55
# 5     pooja      F  1987-05-04     55       64         61       58       75
# 6    Ritesh      M  1989-05-25     54       76         87       56       25
# 7     Farha      F  1990-08-12     55       63         89       75       78
# 8    Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 0         61       58       2
# 1         87       56      74
# 2         89       75      45
# 3         77       83      53
# 4         89       87      52
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding first five 
df.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    Suresh      M  1987-05-04     75       96         78       64       90
# 1    Ramesh      M  1989-05-25     25       54         89       76       95
# 2   Jessica      F  1990-08-12     78       96         86       63       54
# 3  Jennifer      F  1989-09-02     58       96         78       46       96
# 4      Annu      F  1988-04-05     45       87         52       89       55
#
#    Economics  History  Civics
# 0         61       58       2
# 1         87       56      74
# 2         89       75      45
# 3         77       83      53
# 4         89       87      52

# %%
#finding last five columns
df.tail()
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 4    Annu      F  1988-04-05     45       87         52       89       55
# 5   pooja      F  1987-05-04     55       64         61       58       75
# 6  Ritesh      M  1989-05-25     54       76         87       56       25
# 7   Farha      F  1990-08-12     55       63         89       75       78
# 8  Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics
# 4         89       87      52
# 5         58       64      61
# 6         56       76      87
# 7         75       63      89
# 8         83       46      77

# %%
#finding names of the column
df.columns
# Out:
# Index(['Name', 'Gender', 'DOB', 'Maths', 'Physics', 'Chemistry', 'English',
#        'Biology', 'Economics', 'History', 'Civics'],
#       dtype='object')

# %%
#finding datatype
df.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
#finding null values
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %% [markdown]
# Observation: There is no null value present in the given table.

# %%
#finding maximum marks in Maths
df['Maths'].max()
# Out:
# 96

# %%
#finding minimum marks in Maths
df['Maths'].min()
# Out:
# 25

# %%
#finding average marks in Maths
df['Maths'].median()
# Out:
# 55.0

# %%
#Let us find the detail of each subject
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count   9.000000   9.000000   9.000000   9.000000   9.000000   9.000000
# mean   60.111111  75.333333  77.444444  67.777778  69.555556  75.000000
# std    20.569665  19.410049  12.991450  13.908431  23.553721  13.462912
# min    25.000000  46.000000  52.000000  46.000000  25.000000  56.000000
# 25%    54.000000  63.000000  77.000000  58.000000  55.000000  61.000000
# 50%    55.000000  76.000000  78.000000  64.000000  75.000000  77.000000
# 75%    75.000000  96.000000  87.000000  76.000000  90.000000  87.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History     Civics
# count   9.000000   9.000000
# mean   67.555556  60.000000
# std    13.538012  26.828157
# min    46.000000   2.000000
# 25%    58.000000  52.000000
# 50%    64.000000  61.000000
# 75%    76.000000  77.000000
# max    87.000000  89.000000

# %% [markdown]
# Observation: Here we can see that median of maths is low i.e. 55 as compare to other subjects. However the median of chemistry is high i.e. 78. that means more children are under 78. It shows that chenistry results are better as compare to other subjects.
#
# In Maths,physics,Biology childrens are scoring highest score i.e. 96.

# %%
#adding total marks of each child
df['Total']=df.sum(axis=1)

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    Suresh      M  1987-05-04     75       96         78       64       90
# 1    Ramesh      M  1989-05-25     25       54         89       76       95
# 2   Jessica      F  1990-08-12     78       96         86       63       54
# 3  Jennifer      F  1989-09-02     58       96         78       46       96
# 4      Annu      F  1988-04-05     45       87         52       89       55
# 5     pooja      F  1987-05-04     55       64         61       58       75
# 6    Ritesh      M  1989-05-25     54       76         87       56       25
# 7     Farha      F  1990-08-12     55       63         89       75       78
# 8    Mukesh      M  1989-09-02     96       46         77       83       58
#
#    Economics  History  Civics  Total
# 0         61       58       2    695
# 1         87       56      74    635
# 2         89       75      45    760
# 3         77       83      53    741
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='Name',y='Total',data=df)

# %% [markdown]
# Observation: Jessica is holding first position, Jennifer is holding second position and Mukesh is holding third position.

# %%
df['Gender'].value_counts()
# Out:
# F    5
# M    4
# Name: Gender, dtype: int64

# %% [markdown]
# Observation:This shows that there are more females as compare to males.
