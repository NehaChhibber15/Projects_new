# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#reading files by using read_csv
df=pd.read_csv("covid_19_us.csv")
df
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#finding number of rows and columns
df.shape
# Out:
# (58, 18)

# %%
#finding first five rows
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
#finding last five rows
df.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 53       Virginia             US  2020-05-21 02:32:54  37.7693  -78.1700
# 54     Washington             US  2020-05-21 02:32:54  47.4009 -121.4905
# 55  West Virginia             US  2020-05-21 02:32:54  38.4912  -80.9545
# 56      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 57        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 53      32908    1075     4523.0  27310.0    51     385.541875       212626.0
# 54      18971    1037        NaN  17934.0    53     249.130224       293120.0
# 55       1567      69      950.0    548.0    54      87.437024        80641.0
# 56      13413     481     7728.0   5204.0    55     230.367575       167713.0
# 57        787      11      528.0    248.0    56     135.980607        18840.0
#
# ...

# %%
#finding unique numbers 
df.nunique()
# Out:
# Province_State          58
# Country_Region           1
# Last_Update              1
# Lat                     56
# Long_                   56
# Confirmed               58
# Deaths                  56
# Recovered               42
# Active                  58
# FIPS                    58
# Incident_Rate           56
# People_Tested           56
# People_Hospitalized     33
# Mortality_Rate          57
# UID                     58
# ISO3                     6
# Testing_Rate            56
# Hospitalization_Rate    33
# dtype: int64

# %% [markdown]
# Observation:Here Country region and last_update has only one unique value. So we can drop these two columns.

# %%
#removing columns having only one value
df.drop(['Country_Region','Last_Update'],axis=1,inplace=True)
df
# Out:
#               Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 0                    Alabama  32.3182  -86.9023      13052     522        NaN
# 1                     Alaska  61.3707 -152.4044        401      10      352.0
# 2             American Samoa -14.2710 -170.1320          0       0        NaN
# 3                    Arizona  33.7298 -111.4312      14906     747     3773.0
# 4                   Arkansas  34.9697  -92.3731       5003     107     3852.0
# 5                 California  36.1162 -119.6816      85997    3497        NaN
# 6                   Colorado  39.0598 -105.3111      22797    1299     3478.0
# 7                Connecticut  41.5978  -72.7554      39017    3529     6264.0
# 8                   Delaware  39.3185  -75.5071       8194     310     3965.0
# 9           Diamond Princess      NaN       NaN         49       0        NaN
# 10      District of Columbia  38.8974  -77.0268       7551     407     1059.0
# ...

# %%
#finding percentage of null values
df.isnull().sum(axis=0).sort_values(ascending=False)/len(df)*100
# Out:
# Hospitalization_Rate    43.103448
# People_Hospitalized     43.103448
# Recovered               27.586207
# Testing_Rate             3.448276
# People_Tested            3.448276
# Incident_Rate            3.448276
# Long_                    3.448276
# Lat                      3.448276
# Mortality_Rate           1.724138
# ISO3                     0.000000
# UID                      0.000000
# FIPS                     0.000000
# Active                   0.000000
# Deaths                   0.000000
# Confirmed                0.000000
# Province_State           0.000000
# dtype: float64

# %% [markdown]
# Observation: Around 43 % of null values are present in Hospitalization_Rate and People_Hospitalized.
#
# 27% null values present in Recovered column. Rest column having upto 3% of data is missing.

# %%
#finding datatype
df.dtypes
# Out:
# Province_State           object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# # Bivariate Analysis

# %%
#confirmed cases in each Province
df.groupby('Province_State')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Province_State
# New York                    354370
# New Jersey                  150776
# Illinois                    100418
# Massachusetts                88970
# California                   85997
# Pennsylvania                 68126
# Michigan                     53009
# Texas                        51673
# Florida                      47471
# Maryland                     42323
# Georgia                      39801
# Connecticut                  39017
# Louisiana                    35316
# Virginia                     32908
# Ohio                         29436
# Indiana                      29274
# Colorado                     22797
# North Carolina               20262
# Washington                   18971
# Tennessee                    18412
# Minnesota                    17670
# Iowa                         15620
# Arizona                      14906
# Wisconsin                    13413
# Rhode Island                 13356
# Alabama                      13052
# ...

# %% [markdown]
# Observation: Here we can see that the highest number of cases are in the provinces
#
# New York                    354370
#
# New Jersey                  150776
#
# Illinois                    100418
#
# Massachusetts                88970
#
# California                   85997
#
# In newyork there are highest confirmed cases.

# %%
#visualizing confirmed cases in each Province
plt.subplots(figsize=(12,10))
M = df.groupby('Province_State')['Confirmed'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %%
#Number of deaths in each province
df.groupby('Province_State')['Deaths'].sum().sort_values(ascending=False)
# Out:
# Province_State
# New York                    28636
# New Jersey                  10749
# Massachusetts                6066
# Michigan                     5060
# Pennsylvania                 4770
# Illinois                     4525
# Connecticut                  3529
# California                   3497
# Louisiana                    2608
# Maryland                     2123
# Florida                      2096
# Indiana                      1864
# Ohio                         1781
# Georgia                      1697
# Texas                        1426
# Colorado                     1299
# Virginia                     1075
# Washington                   1037
# Minnesota                     786
# Arizona                       747
# North Carolina                726
# Missouri                      640
# Mississippi                   570
# Rhode Island                  538
# Alabama                       522
# Wisconsin                     481
# South Carolina                407
# ...

# %% [markdown]
# Observation: Here we observed that maximum number of deaths are in the province of
#
# New York                    28636
#
# New Jersey                  10749
#
# Massachusetts                6066
#
# Michigan                     5060
#
# Pennsylvania                 4770
#
# Although Illinois has maximum confirmed cases but the number of deaths are less. Here Massachusetts stood at third position.

# %%
#Visualizing number of deaths in each province
plt.subplots(figsize=(12,10))
M = df.groupby('Province_State')['Deaths'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %%
#Number of recovered cases in each Province
df.groupby('Province_State')['Recovered'].sum().sort_values(ascending=False)
# Out:
# Province_State
# New York                    61886.0
# Texas                       30341.0
# Michigan                    28234.0
# Louisiana                   26249.0
# New Jersey                  23945.0
# Minnesota                   12227.0
# Tennessee                   11783.0
# North Carolina              11637.0
# Iowa                         8362.0
# Wisconsin                    7728.0
# Mississippi                  7681.0
# Connecticut                  6264.0
# South Carolina               5451.0
# Virginia                     4523.0
# Utah                         4423.0
# Oklahoma                     4266.0
# Delaware                     3965.0
# Arkansas                     3852.0
# Arizona                      3773.0
# Colorado                     3478.0
# South Dakota                 3023.0
# Maryland                     2993.0
# Kentucky                     2826.0
# New Mexico                   1882.0
# Idaho                        1668.0
# ...

# %% [markdown]
# Observation: Here top 5 province in which people recovering fastly are
#
# New York                    61886.0
#
# Texas                       30341.0
#
# Michigan                    28234.0
#
# Louisiana                   26249.0
#
# New Jersey                  23945.0
#
# We can see that Texas province is doing better. Although it is not in the list of top 5 maximum confirmed cases and death cases.

# %%
#Number of recovered cases in each Province
plt.subplots(figsize=(12,10))
M = df.groupby('Province_State')['Recovered'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %%
#Visualizing number of people_tested in each province
plt.subplots(figsize=(12,10))
M=df.groupby('Province_State')['People_Tested'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %% [markdown]
# Observation:Here we can see that more testing is done in Newyork, California,Florida,Texas,iilinois,New Jersey. As we can see that number of confirmed cases are more in these regions that's why govt is taking strict measure to control the disease.

# %%
#visualizing people hospitalizes in different region
plt.subplots(figsize=(12,10))
M=df.groupby('Province_State')['People_Hospitalized'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %% [markdown]
# Here we can see that majority of people are hospitalized in Newyork Province.

# %%
plt.subplots(figsize=(12,10))
M=df.groupby('Confirmed')['People_Hospitalized'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %%
#visualizing mortality rate in each province
plt.subplots(figsize=(12,10))
M=df.groupby('Province_State')['Mortality_Rate'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %% [markdown]
# Observation: Michigan, Northern Mariana Island, Connecticut,virgin Island have very high mortality rate despite of less cases as compare to other province. May be the medical resources are very less here.

# %%
#visualizing testing rate in each province
plt.subplots(figsize=(12,10))
M=df.groupby('Province_State')['Testing_Rate'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %% [markdown]
# Observation: Here we can see that Rhoden Island, North Dakota, Newyork had done more testing as compare to other province.

# %%
#visualization of rate of hospitalization in different province
plt.subplots(figsize=(12,10))
M=df.groupby('Province_State')['Hospitalization_Rate'].sum().sort_values(ascending=False)
M.plot.bar()
plt.show()

# %% [markdown]
# Observation: Here we can see that people in provinces like connecticut, kentucky, Newyork, Oregon, Florida need more hospitalization as compare to other province. May be in this region people are very less immune to disease.

# %%
#Visualizing relation between confirmed cases, deaths, Recovered in each province
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Province_State",y="Confirmed",color='r',data=df)
sns.barplot(x="Province_State",y="Deaths",color='g',data=df)
sns.barplot(x="Province_State",y="Recovered",color='b',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation: In newyork despite of majority of cases people are recovering more. However Massachusetts is in bad shape, there are more death in this region. Very less people are recovering here. Same is the case with Pennsylvania. In louisiana maximum strength of people are recovered.

# %%
#finding null values
df.isnull().sum()
# Out:
# Province_State           0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
#doing statistical Analysis
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# ...

# %% [markdown]
# # Handling Missing Values

# %%
#filling the null values for numerical data with their mean
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(missing_values = np.nan, strategy ='median')

# %%
df['Recovered']=imputer.fit_transform(df['Recovered'].values.reshape(-1,1))

# %%
df['People_Hospitalized']=imputer.fit_transform(df['People_Hospitalized'].values.reshape(-1,1))

# %%
df['Hospitalization_Rate']=imputer.fit_transform(df['Hospitalization_Rate'].values.reshape(-1,1))

# %%
df
# Out:
#               Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 0                    Alabama  32.3182  -86.9023      13052     522     3008.0
# 1                     Alaska  61.3707 -152.4044        401      10      352.0
# 2             American Samoa -14.2710 -170.1320          0       0     3008.0
# 3                    Arizona  33.7298 -111.4312      14906     747     3773.0
# 4                   Arkansas  34.9697  -92.3731       5003     107     3852.0
# 5                 California  36.1162 -119.6816      85997    3497     3008.0
# 6                   Colorado  39.0598 -105.3111      22797    1299     3478.0
# 7                Connecticut  41.5978  -72.7554      39017    3529     6264.0
# 8                   Delaware  39.3185  -75.5071       8194     310     3965.0
# 9           Diamond Princess      NaN       NaN         49       0     3008.0
# 10      District of Columbia  38.8974  -77.0268       7551     407     1059.0
# ...

# %%
#dropping remaining null values 
df.dropna(inplace=True)
df
# Out:
#               Province_State      Lat     Long_  Confirmed  Deaths  Recovered  \
# 0                    Alabama  32.3182  -86.9023      13052     522     3008.0
# 1                     Alaska  61.3707 -152.4044        401      10      352.0
# 3                    Arizona  33.7298 -111.4312      14906     747     3773.0
# 4                   Arkansas  34.9697  -92.3731       5003     107     3852.0
# 5                 California  36.1162 -119.6816      85997    3497     3008.0
# 6                   Colorado  39.0598 -105.3111      22797    1299     3478.0
# 7                Connecticut  41.5978  -72.7554      39017    3529     6264.0
# 8                   Delaware  39.3185  -75.5071       8194     310     3965.0
# 10      District of Columbia  38.8974  -77.0268       7551     407     1059.0
# 11                   Florida  27.7663  -81.6868      47471    2096     3008.0
# 12                   Georgia  33.0406  -83.6431      39801    1697     3008.0
# ...

# %%
#verifying null values
df.isnull().sum()
# Out:
# Province_State          0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
#finding correlation
df.corr()
# Out:
#                            Lat     Long_  Confirmed    Deaths  Recovered  \
# Lat                   1.000000 -0.570065   0.098689  0.110710   0.049867
# Long_                -0.570065  1.000000  -0.006640  0.016533  -0.031919
# Confirmed             0.098689 -0.006640   1.000000  0.982353   0.792838
# Deaths                0.110710  0.016533   0.982353  1.000000   0.810759
# Recovered             0.049867 -0.031919   0.792838  0.810759   1.000000
# Active                0.100299 -0.004159   0.985028  0.954112   0.678289
# FIPS                 -0.331101  0.433423  -0.091928 -0.061217   0.010785
# Incident_Rate         0.210072  0.010608   0.710461  0.712258   0.535707
# People_Tested         0.024969 -0.105068   0.827191  0.741134   0.651786
# People_Hospitalized   0.061364  0.042615   0.860190  0.900576   0.722141
# Mortality_Rate       -0.189675  0.318569   0.375722  0.427860   0.316599
# UID                   0.718638 -0.714161   0.144630  0.112576   0.144121
# ...

# %%
#visualization of correlation by using heatmap
plt.subplots(figsize=(18, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation: Here we can see that FIPS,Lat,Long_ is very less correlated with other columns. So we can drop these columns.

# %%
#transforming categorical values in the numberic values
from sklearn.preprocessing import LabelEncoder
df['Province_State']=LabelEncoder().fit_transform(df['Province_State'])

# %%
df
# Out:
#     Province_State      Lat     Long_  Confirmed  Deaths  Recovered    Active  \
# 0                0  32.3182  -86.9023      13052     522     3008.0   12530.0
# 1                1  61.3707 -152.4044        401      10      352.0      39.0
# 3                2  33.7298 -111.4312      14906     747     3773.0   10386.0
# 4                3  34.9697  -92.3731       5003     107     3852.0    1044.0
# 5                4  36.1162 -119.6816      85997    3497     3008.0   82500.0
# 6                5  39.0598 -105.3111      22797    1299     3478.0   18020.0
# 7                6  41.5978  -72.7554      39017    3529     6264.0   29224.0
# 8                7  39.3185  -75.5071       8194     310     3965.0    3919.0
# 10               8  38.8974  -77.0268       7551     407     1059.0    6085.0
# 11               9  27.7663  -81.6868      47471    2096     3008.0   45375.0
# 12              10  33.0406  -83.6431      39801    1697     3008.0   38104.0
# ...

# %%
#Visualizing data by using boxplot
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# Observation: Here we can see that somewhere data is skewed. So we need to normalize it.

# %%
#dividing the data into dependent and independent variable
x=df.drop(columns=['Deaths','Lat','Long_','FIPS','UID','ISO3'],axis=1)
y=df['Deaths']

# %%
#nomalizing the curve
#transforming the data to reduce skewness
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()
x=scale.fit_transform(x)

# %%
#Here we will find out the random state value with which our linear model will learn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
#finding best randomstate for train test split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# r2 score corresponding to 42 is 0.9839256278636951
# r2 score corresponding to 43 is 0.9382435574154014
# r2 score corresponding to 44 is 0.9789291348038858
# r2 score corresponding to 45 is 0.8145207144914257
# r2 score corresponding to 46 is 0.8264914378810997
# r2 score corresponding to 47 is 0.8283992097300332
# r2 score corresponding to 48 is 0.8688283489007237
# r2 score corresponding to 49 is 0.9324839811995286
# r2 score corresponding to 50 is 0.9269505992111687
# r2 score corresponding to 51 is 0.9095598173360234
# r2 score corresponding to 52 is 0.4224682374463373
# r2 score corresponding to 53 is 0.9622086597276456
# r2 score corresponding to 54 is 0.9643823509499457
# r2 score corresponding to 55 is 0.9625885558643043
# r2 score corresponding to 56 is -0.5401495645806147
# r2 score corresponding to 57 is 0.9917287838563794
# r2 score corresponding to 58 is 0.46247995321474866
# r2 score corresponding to 59 is 0.8517565583585429
# ...

# %%
#splitting the data for train and test
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=57,test_size=0.20)

# %%
#lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Hyperparameter tunning by using grid search cv

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 4}

# %%
#importing regression alogorithms from sklearn
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
#finding best parameter for ridge by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
rg=Ridge()
grg=GridSearchCV(rg,param_grid=alphavalue)
grg.fit(x,y)
grg.best_params_
# Out:
# {'alpha': 0}

# %%
#finding best parameter for lasso by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
las=Lasso()
lasg=GridSearchCV(las,param_grid=alphavalue)
lasg.fit(x,y)
lasg.best_params_
# Out:
# {'alpha': 0}

# %%
#finding best parameter for randomforest by using grid search cv
rfr = RandomForestRegressor()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfr, param_grid, n_jobs=-1, cv=5)

grid.fit(x, y)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'log2',
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
#finding best parameters for support vector regressor by using grid search cv
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.4270925598414195
# linear
# {'C': 10, 'kernel': 'linear'}

# %%
#finding best parameter for decision tree regressor by using grid search cv
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x,y)
grid_cv_dtm.best_params_
# Out:
# {'criterion': 'mae',
#  'max_depth': 2,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 40,
#  'min_samples_split': 10}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,25)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x,y)
gad.best_params_
# Out:
# {'n_estimators': 13}

# %%
#fitting parameters in our algorithms
knr=KNeighborsRegressor(n_neighbors=4)
rg=Ridge(alpha=0)
las=Lasso(alpha=0)
svr=SVR(C= 10, kernel= 'linear')
lr=LinearRegression(normalize=True)
dtr=DecisionTreeRegressor(criterion= 'mae', max_depth= 2, max_leaf_nodes= 5, min_samples_leaf= 40, min_samples_split= 10)
rfr=RandomForestRegressor(bootstrap= True, max_features='log2',min_samples_split= 2,n_estimators=10)
ad=AdaBoostRegressor(n_estimators=13)

# %%
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('Ridge',rg))
models.append(('Lasso',las))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
#for loop for all the algorithms along with their cross validation
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score=',sc)
    sc1=sc*100
    cvs.append(sc1)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                     weights='uniform')
#
#
# score: 0.8234182641648853
# mean squared error 54766644.78977273
# mean absolute error 2941.25
# r2_score 0.18177500469718844
#
#
# Cross_Val_Score= 0.48609189730853936
#
#
# ************ Ridge ************
#
#
# Ridge(alpha=0, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)
#
#
# score: 0.948515349297199
# mean squared error 553621.2644655985
# mean absolute error 428.23225918379177
# r2_score 0.9917287838563831
#
#
# Cross_Val_Score= 0.46171035775615793
#
#
# ************ Lasso ************
#
#
# Lasso(alpha=0, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
# ...

# %%
#arranging results in a tabularform
result=pd.DataFrame({'Model':Model,'score':sco,'R2_score':r2score})
result
# Out:
#                    Model     score   R2_score
# 0    KNeighborsRegressor  0.823418  18.177500
# 1                  Ridge  0.948515  99.172878
# 2                  Lasso  0.948277  98.984032
# 3   SupportVectorMachine  0.273038   8.073297
# 4        LinearRegressor  0.948515  99.172878
# 5  DecisionTreeRegressor -0.173010 -24.546947
# 6  RandomForestRegressor  0.956459  21.476714
# 7      AdaBoostRegressor  0.992544  19.204121

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(lr,'covid.pkl')
# Out:
# ['covid.pkl']
