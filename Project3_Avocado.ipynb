# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#reading csv file by using read.csv command and placing the date column in proper format by changing into datetype from string type
df=pd.read_csv('avocado.csv',parse_dates=['Date'])
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1             1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2             2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3             3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4             4.0 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 16463         NaN        NaT           NaN           NaN      NaN        NaN
# 16464         NaN        NaT           NaN           NaN      NaN        NaN
# 16465         NaN        NaT           NaN           NaN      NaN        NaN
# 16466         NaN        NaT           NaN           NaN      NaN        NaN
# 16467         NaN        NaT           NaN           NaN      NaN        NaN
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#checking number of rows and columns in dataset
df.shape
# Out:
# (16468, 14)

# %%
#checking the names of columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#finding first 5 rows
df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1         1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2         2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3         3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4         4.0 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %%
#finding last 5 rows
df.tail()
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16463         NaN  NaT           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaT           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaT           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaT           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaT           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16463         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16464         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16465         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16466         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16467         NaN         NaN         NaN          NaN  NaN   NaN    NaN

# %% [markdown]
# Observation: This shows that in the end of dataset there are some blank rows. Now, let us remove blank rows present at the end of the data set.

# %%
df=df.dropna()
df
#dropping all the blank rows from the dataset
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0 2015-12-27          1.33      64236.62   1036.74   54454.85
# 1            1.0 2015-12-20          1.35      54876.98    674.28   44638.81
# 2            2.0 2015-12-13          0.93     118220.22    794.70  109149.67
# 3            3.0 2015-06-12          1.08      78992.15   1132.00   71976.41
# 4            4.0 2015-11-29          1.28      51039.60    941.48   43838.39
# ...          ...        ...           ...           ...       ...        ...
# 1512        10.0 2016-10-16          1.39     190846.01  57529.11   56366.66
# 1513        11.0 2016-09-10          1.51     178235.75  43325.87   52189.61
# 1514        12.0 2016-02-10          1.48     178410.82  46364.75   52893.38
# 1515        13.0 2016-09-25          1.47     189131.52  54110.79   53593.58
# 1516        14.0 2016-09-18          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
#droping Unnamed column as it seems not usefull.
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Observation: As this column is just representing index so it is of no use. So we can drop that column.

# %%
#checking our dataframe to ensure that whether the column is removed or not
df
# Out:
#            Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0    2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1    2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2    2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3    2015-06-12          1.08      78992.15   1132.00   71976.41     72.58
# 4    2015-11-29          1.28      51039.60    941.48   43838.39     75.78
# ...         ...           ...           ...       ...        ...       ...
# 1512 2016-10-16          1.39     190846.01  57529.11   56366.66  17531.78
# 1513 2016-09-10          1.51     178235.75  43325.87   52189.61  19419.57
# 1514 2016-02-10          1.48     178410.82  46364.75   52893.38  16736.92
# 1515 2016-09-25          1.47     189131.52  54110.79   53593.58  17495.42
# 1516 2016-09-18          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
#Let us check details of our dataset i.e its datatype, null value and memory information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   datetime64[ns]
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   float64
#  12  region        1517 non-null   object
# dtypes: datetime64[ns](1), float64(10), object(2)
# memory usage: 165.9+ KB

# %% [markdown]
# Observation: Here we observe that there is no null value present. Rest we have two object datatype in our dataframe. Now, let us do some feature engineering.

# %% [markdown]
# # Feature Engineering

# %%
#let us check decriptive statistics for all the columns
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %% [markdown]
# Observation: Here we can see that the average price of avocado is of 1.080. However the minimum price are of 0.49 and maximum price are of 1.68. We can also get an idea of range of year i.e. 2015 to 2016. Here we can see that in XLarge Bags, there is a huge difference between 75 percentile and 100 percentile. May be some outliers present.

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Observation: Here, we can observe that there is no null value present in our data.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# First let us explore the type of avocado. Here it is of two type conventional and Organic. As we know in organic farming no chemical fertilizers are used to enhance the fertility of solid. So it is consider as best for our health. However the production rate is very slow in that case. Let us check whether it is same case with our dataset or not.

# %% [markdown]
# Let's check which is more in demand organic or conventional.

# %%
df.type.value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
#visualizing type of avocado
plt.figure(figsize=(15,10))
sns.countplot(df.type)
plt.xticks(rotation=0)
# Out:
# (array([0]), <a list of 1 Text xticklabel objects>)

# %% [markdown]
# Observation: Here we observe that type of avocado in our dataset is of conventional. There is no organic type present.

# %% [markdown]
# Now, let us visualize the average price of avocado by using distplot

# %%
#visualizing average prize of avocado
plt.subplots(figsize=(15, 9))
sns.distplot(a=df.AveragePrice, kde=True)

# %% [markdown]
# Observation:Here we observe that the average price of avocado is 1.1(approx). However the minimum prize of avocado is of 0.4(approx.) and maximum prize 1.7(approx.)

# %%
#Now let us check how the month impact the average price of avocado
#seperating date into month,day, year
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)
df['year']=df['Date'].apply(lambda x:x.year)

# %%
#visualizing relation between month and average price
plt.figure(figsize=(18,10))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# Observation:Here we observe that in a month of jan there average prices are less However in a month of november their prices are very high. May be due to different climatic conditions there production varies which impact the average price of fruit.

# %% [markdown]
# Now, let us visualize the relation between average prices in different region

# %%
#finding average price of top regions
reg_list=list(df.region.unique())
average_price=[]

for i in reg_list:
    x=df[df.region==i]
    reg_average=sum(x.AveragePrice)/len(x)
    average_price.append(reg_average)

df1=pd.DataFrame({'reg_list':reg_list,'average_price':average_price})
new_index=df1.average_price.sort_values(ascending=False).index.values
sort_data=df1.reindex(new_index)

plt.figure(figsize=(30,15))
ax=sns.barplot(x=sort_data.reg_list,y=sort_data.average_price,label='big')

plt.xticks(rotation=90)
plt.xlabel('Region',fontsize=30)
plt.ylabel('Average Price',fontsize=20)
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %% [markdown]
# Observation: Here we observed that which regions have high average prices.

# %%
#finding region having maximum consumption

region_list=list(df.region.unique())
average_total_volume=[]

for i in region_list:
    x=df[df.region==i]
    average_total_volume.append(sum(x['Total Volume'])/len(x))
df2=pd.DataFrame({'region_list':region_list,'average_total_volume':average_total_volume})

new_index=df2.average_total_volume.sort_values(ascending=False).index.values
sorted_data1=df2.reindex(new_index)

plt.figure(figsize=(22,10))
ax=sns.barplot(x=sorted_data1.region_list,y=sorted_data1.average_total_volume)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average of Total Volume')
plt.title('Average of Total Volume According to Region')
# Out:
# Text(0.5, 1.0, 'Average of Total Volume According to Region')

# %% [markdown]
# Observation: Here, we observe that the consumption is maximum in the region of california,west,south central, North east.

# %%
#finding unique value of region
df['region'].nunique()
# Out:
# 51

# %%
#finding types
df['type'].nunique()
# Out:
# 1

# %%
#finding correlation between different attributes.
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# Month             0.060642     -0.055212 -0.053007 -0.058429 -0.055079
# Day               0.092589     -0.034857 -0.031806 -0.044008 -0.021318
#
# ...

# %%
#visualization of correlation by using heatmap
plt.subplots(figsize=(15, 8))
sns.heatmap(df.corr(),annot=True,linewidths=.5)

# %% [markdown]
# Observation:Here we observe that all the features are very less correlated with Average price, instead that they are more correlated with each other.

# %%
#checking our data
df
# Out:
#            Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0    2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1    2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2    2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3    2015-06-12          1.08      78992.15   1132.00   71976.41     72.58
# 4    2015-11-29          1.28      51039.60    941.48   43838.39     75.78
# ...         ...           ...           ...       ...        ...       ...
# 1512 2016-10-16          1.39     190846.01  57529.11   56366.66  17531.78
# 1513 2016-09-10          1.51     178235.75  43325.87   52189.61  19419.57
# 1514 2016-02-10          1.48     178410.82  46364.75   52893.38  16736.92
# 1515 2016-09-25          1.47     189131.52  54110.79   53593.58  17495.42
# 1516 2016-09-18          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
#Here we have taken month and day seperately. So we can drop date column.
df.drop('Date',axis=1,inplace=True)

# %%
#checking data again to ensure the removal of date column
df
# Out:
#       AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0             1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1             1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2             0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3             1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4             1.28      51039.60    941.48   43838.39     75.78     6183.95
# ...            ...           ...       ...        ...       ...         ...
# 1512          1.39     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513          1.51     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514          1.48     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515          1.47     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516          1.43     182978.30  43116.41   54193.42  16563.91    69104.56
#
# ...

# %% [markdown]
# # Building a model to predict average price by using regression

# %%
x=df[['4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]

# %%
x
# Out:
#           4046       4225      4770  Total Bags  Small Bags  Large Bags  \
# 0      1036.74   54454.85     48.16     8696.87     8603.62       93.25
# 1       674.28   44638.81     58.33     9505.56     9408.07       97.49
# 2       794.70  109149.67    130.50     8145.35     8042.21      103.14
# 3      1132.00   71976.41     72.58     5811.16     5677.40      133.76
# 4       941.48   43838.39     75.78     6183.95     5986.26      197.69
# ...        ...        ...       ...         ...         ...         ...
# 1512  57529.11   56366.66  17531.78    59418.46    48823.53    10354.65
# 1513  43325.87   52189.61  19419.57    63300.70    54704.14     8596.56
# 1514  46364.75   52893.38  16736.92    62415.77    53332.61     8258.16
# 1515  54110.79   53593.58  17495.42    63931.73    55653.47     8278.26
# 1516  43116.41   54193.42  16563.91    69104.56    57456.21    11648.35
#
#       XLarge Bags
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# ...

# %%
y=df[['AveragePrice']]

# %%
#visualizing distplot of each column
for i in x.describe().columns:
    sns.distplot(x[i])
    plt.show()

# %%
#scaling the input variable
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x= sc.fit_transform(x)

# %%
x
# Out:
# array([[-0.33149016, -0.33305294, -0.3656081 , ..., -0.37105465,
#         -0.36004386, -0.29272731],
#        [-0.33167633, -0.33892254, -0.36553427, ..., -0.3698118 ,
#         -0.36000798, -0.29272731],
#        [-0.33161448, -0.30034767, -0.36501029, ..., -0.37192201,
#         -0.35996017, -0.29272731],
#        ...,
#        [-0.30820887, -0.33398664, -0.24444312, ..., -0.30194984,
#         -0.29095317, -0.1820374 ],
#        [-0.30423037, -0.33356795, -0.2389362 , ..., -0.29836419,
#         -0.29078309, -0.29272731],
#        [-0.30987728, -0.33320927, -0.24569922, ..., -0.29557902,
#         -0.26226571, -0.29272731]])

# %%
x1=pd.DataFrame(x)

# %%
x1.columns=['4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']

# %%
x1
# Out:
#           4046      4225      4770  Total Bags  Small Bags  Large Bags  \
# 0    -0.331490 -0.333053 -0.365608   -0.375994   -0.371055   -0.360044
# 1    -0.331676 -0.338923 -0.365534   -0.374927   -0.369812   -0.360008
# 2    -0.331614 -0.300348 -0.365010   -0.376722   -0.371922   -0.359960
# 3    -0.331441 -0.322576 -0.365431   -0.379802   -0.375576   -0.359701
# 4    -0.331539 -0.339401 -0.365408   -0.379310   -0.375098   -0.359160
# ...        ...       ...       ...         ...         ...         ...
# 1512 -0.302475 -0.331910 -0.238672   -0.309055   -0.308916   -0.273213
# 1513 -0.309770 -0.334407 -0.224966   -0.303931   -0.299831   -0.288090
# 1514 -0.308209 -0.333987 -0.244443   -0.305099   -0.301950   -0.290953
# 1515 -0.304230 -0.333568 -0.238936   -0.303098   -0.298364   -0.290783
# 1516 -0.309877 -0.333209 -0.245699   -0.296272   -0.295579   -0.262266
#
#       XLarge Bags
# 0       -0.292727
# 1       -0.292727
# 2       -0.292727
# 3       -0.292727
# ...

# %%
x1.skew()
# Out:
# 4046           6.051830
# 4225           6.394926
# 4770           5.405164
# Total Bags     5.366378
# Small Bags     5.355185
# Large Bags     5.144495
# XLarge Bags    5.775077
# dtype: float64

# %%
#Here we will find out the random state value with which our linear model will learn
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
#finding best randomstate for train test split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to",r_state,"is",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to",final_r_state,"is",max_r_score)  
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
r_state=maxr2_score(regr,x1,y)
# Out:
# r2 score corresponding to 42 is 0.14108971868206632
# r2 score corresponding to 43 is 0.12712815528297117
# r2 score corresponding to 44 is 0.14231390260233823
# r2 score corresponding to 45 is 0.11954026478887203
# r2 score corresponding to 46 is 0.19839314604078695
# r2 score corresponding to 47 is 0.15105762447125404
# r2 score corresponding to 48 is 0.08893494158295912
# r2 score corresponding to 49 is 0.09404550975428272
# r2 score corresponding to 50 is 0.1351595364600776
# r2 score corresponding to 51 is 0.16948100487406925
# r2 score corresponding to 52 is 0.19687956618128188
# r2 score corresponding to 53 is 0.2099437916661142
# r2 score corresponding to 54 is 0.16586258449393299
# r2 score corresponding to 55 is 0.18725022046290984
# r2 score corresponding to 56 is 0.10030743956132049
# r2 score corresponding to 57 is 0.13206847169983138
# r2 score corresponding to 58 is 0.1003584620386001
# r2 score corresponding to 59 is 0.1469211293101247
# ...

# %%
#splitting the data for train and test
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=53,test_size=0.20)

# %%
#lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# # Hyperparameter tunning by using grid search cv

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,20)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x1,y)
gknr.best_params_
# Out:
# {'n_neighbors': 19}

# %%
#importing regression alogorithms from sklearn
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
#finding best parameter for ridge by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
rg=Ridge()
grg=GridSearchCV(rg,param_grid=alphavalue)
grg.fit(x1,y)
grg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for lasso by using grid search cv
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
las=Lasso()
lasg=GridSearchCV(las,param_grid=alphavalue)
lasg.fit(x1,y)
lasg.best_params_
# Out:
# {'alpha': 1}

# %%
#finding best parameter for randomforest by using grid search cv
rfr = RandomForestRegressor()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfr, param_grid, n_jobs=-1, cv=5)

grid.fit(x1, y)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'log2',
#  'min_samples_split': 8,
#  'n_estimators': 30}

# %%
#finding best parameters for support vector regressor by using grid search cv
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
svr=SVR()
clf=GridSearchCV(svr,parameters)
clf.fit(x1,y)
print(clf.best_score_)
print(clf.best_estimator_.kernel)
print(clf.best_params_)
# Out:
# 0.2261062392638668
# rbf
# {'C': 10, 'kernel': 'rbf'}

# %%
#finding best parameter for decision tree regressor by using grid search cv
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x1,y)
grid_cv_dtm.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 6,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 20,
#  'min_samples_split': 10}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,25)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x1,y)
gad.best_params_
# Out:
# {'n_estimators': 5}

# %%
#fitting parameters in our algorithms
knr=KNeighborsRegressor(n_neighbors=19)
rg=Ridge(alpha=1)
las=Lasso(alpha=1)
svr=SVR(C= 10, kernel= 'rbf')
lr=LinearRegression(normalize=True)
dtr=DecisionTreeRegressor(criterion= 'mse', max_depth= 6, max_leaf_nodes= 5, min_samples_leaf= 20, min_samples_split= 10)
rfr=RandomForestRegressor(bootstrap= True, max_features='log2',min_samples_split= 8,n_estimators=30)
ad=AdaBoostRegressor(n_estimators=5)

# %%
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('Ridge',rg))
models.append(('Lasso',las))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
#for loop for all the algorithms along with their cross validation
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score=',sc)
    sc1=sc*100
    cvs.append(sc1)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=19, p=2,
#                     weights='uniform')
#
#
# score: 0.6573142627793973
# mean squared error 0.01269960362297711
# mean absolute error 0.08422957063711911
# r2_score 0.6496048572521713
#
#
# Cross_Val_Score= -0.20828977109059993
#
#
# ************ Ridge ************
#
#
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)
#
#
# score: 0.13404043352114547
# mean squared error 0.028676500830391218
# mean absolute error 0.129087069566973
# r2_score 0.20878580936232205
#
#
# Cross_Val_Score= -0.44938314523230194
#
#
# ************ Lasso ************
#
#
# Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
# ...

# %%
#arranging results in a tabularform
result=pd.DataFrame({'Model':Model,'score':sco,'R2_score':r2score})
result
# Out:
#                    Model     score   R2_score
# 0    KNeighborsRegressor  0.657314  64.960486
# 1                  Ridge  0.134040  20.878581
# 2                  Lasso  0.000000  -0.806917
# 3   SupportVectorMachine  0.516616  54.891970
# 4        LinearRegressor  0.134069  20.994379
# 5  DecisionTreeRegressor  0.435676  42.633527
# 6  RandomForestRegressor  0.918939  77.493485
# 7      AdaBoostRegressor  0.546504  52.187748

# %% [markdown]
# Observation: Here,we find that randomforest regressor is giving good results as compare to others. So, let's finalize this model.

# %% [markdown]
# # Predicting Region by using classification model

# %%
#creating new dataframe for this part
x2=df[['AveragePrice','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]

# %%
#new target
y1=df['region']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
le=LabelEncoder()
y1=le.fit_transform(y1)

# %%
y1
# Out:
# array([0, 0, 0, ..., 7, 7, 7])

# %%
#splitting the data into train and test by using train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(x2,y1,test_size=.22,random_state=42)

# %%
#importing different classifier algorithms
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# # Hyperparameter tunning by using grid search cv

# %%
#finding best parameter for knn classifier by using grid search cv
neighbors={"n_neighbors":range(1,20)}
knc=KNeighborsClassifier()
gknc=GridSearchCV(knc,neighbors,cv=10)
gknc.fit(x2,y1)
gknc.best_params_
# Out:
# {'n_neighbors': 1}

# %%
#finding best parameter for randomforest classifier by using grid search cv
rfc = RandomForestClassifier()
param_grid = {
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

grid = GridSearchCV(rfc, param_grid, n_jobs=-1, cv=5)

grid.fit(x2, y1)
grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'sqrt',
#  'min_samples_split': 4,
#  'n_estimators': 30}

# %%
#finding best parameter for adaboost classifier by using grid search cv
n_estimators={"n_estimators":range(1,25)}
adc=AdaBoostClassifier()
gadc=GridSearchCV(adc,n_estimators,cv=10)
gadc.fit(x2,y1)
gadc.best_params_
# Out:
# {'n_estimators': 13}

# %%
#finding best parameter for decision tree classifier by using grid search cv
param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
dtc=DecisionTreeClassifier()    
gdtc=GridSearchCV(dtc, param_grid, cv=5)
gdtc.fit(x2, y1)
gdtc.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8}

# %%
knc=KNeighborsClassifier(n_neighbors=1)
svc=SVC()
dtc=DecisionTreeClassifier(criterion='entropy', max_depth=8)
rfc=RandomForestClassifier(bootstrap= True, max_features='sqrt',min_samples_split= 4,n_estimators=30)
adc=AdaBoostClassifier(n_estimators=13)

# %%
models=[]
models.append(('KNeighborsClassifier',knc))
models.append(('SupportVectorClassifier',svc))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifierClassifier',adc))
models.append(('DecisionTreeClassifier',dtc))

# %%
#importing metrics for finding error
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Models=[]
score=[]
cvs=[]
cm1=[]
rocscore=[]
for name,model in models:
    print('*****************',name,'**********************')
    print('\n')
    Models.append(name)
    model.fit(x_train1,y_train1)
    print(model)
    pre=model.predict(x_test1)
    print('\n')
    AS=accuracy_score(y_test1,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x2,y1,cv=10,scoring='accuracy').mean()
    print('Cross_val_score=',sc)
    cvs.append(sc*100)
    print('\n')    
    print('classification_report\n',classification_report(y_test1,pre))
    print('\n')
    cm=confusion_matrix(y_test1,pre)
    print(cm)
# Out:
# ***************** KNeighborsClassifier **********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8712574850299402
#
#
# Cross_val_score= 0.8497865109794354
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87        11
#            1       1.00      0.73      0.85        15
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        12
#            4       0.70      0.88      0.78         8
#            5       0.86      0.75      0.80         8
#            6       0.86      0.95      0.90        19
#            7       1.00      1.00      1.00        10
#            8       1.00      1.00      1.00         7
#            9       1.00      0.90      0.95        10
# ...

# %%
result=pd.DataFrame({'Model':Models,'Accuracy_score':score,'Cross_val_score':cvs})
result
# Out:
#                           Model  Accuracy_score  Cross_val_score
# 0          KNeighborsClassifier       87.125749        84.978651
# 1       SupportVectorClassifier       23.652695        27.622865
# 2        RandomForestClassifier       96.107784        93.472900
# 3  AdaBoostClassifierClassifier       12.874251        12.393255
# 4        DecisionTreeClassifier       86.526946        85.229174

# %% [markdown]
# Observation: Here we can see that RandomForestClassifier is giving accurate results among all. So we can finalize this model.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(rfc,'avocado1.pkl')
# Out:
# ['avocado1.pkl']

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(rfr,'avocado2.pkl')
# Out:
# ['avocado2.pkl']
